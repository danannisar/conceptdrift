# %%
import numpy as np
import pandas as pd
# Out:
# C:\Users\247\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from sklearn.feature_extraction.text import CountVectorizer

texts = open('C:/Users/247/Documents/Python Scripts/datasets/reuters.titles').read().splitlines()[:50]
vec = CountVectorizer(stop_words='english')
X = vec.fit_transform(texts).toarray()

# %%
texts
# Out:
# C:\Users\247\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['UK: Prince Charles spearheads British royal revolution.',
#  'GERMANY: Historic Dresden church rising from WW2 ashes.',
#  "INDIA: Mother Teresa's condition said still unstable.",
#  'UK: Palace warns British weekly over Charles pictures.',
#  'INDIA: Mother Teresa, slightly stronger, blesses nuns.',
#  "INDIA: Mother Teresa's condition unchanged, thousands pray.",
#  'INDIA: Mother Teresa shows signs of strength, blesses nuns.',
#  "INDIA: Mother Teresa's condition improves, many pray.",
#  'INDIA: Mother Teresa improves, nuns pray for "miracle".',
#  'UK: Charles under fire over prospect of Queen Camilla.',
# ...

# %%
from biterm.utility import vec_to_biterms

vocab = np.array(vec.get_feature_names())
biterms = vec_to_biterms(X)

# %%
from biterm.btm import oBTM

btm = oBTM(num_topics=20, V=vocab)
topics = btm.fit_transform(biterms, iterations=100)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:06<00:00, 15.93it/s]

# %%
texts_pd = pd.DataFrame({'title': texts})
texts_pd
# Out:
# C:\Users\247\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                                  title
# 0    UK: Prince Charles spearheads British royal re...
# 1    GERMANY: Historic Dresden church rising from W...
# 2    INDIA: Mother Teresa's condition said still un...
# 3    UK: Palace warns British weekly over Charles p...
# 4    INDIA: Mother Teresa, slightly stronger, bless...
# ..                                                 ...
# 390  CANADA: FEATURE - French-speaking Quebec celeb...
# 391  BULGARIA: FEATURE - Bulgarian opera stars are ...
# 392     USA: Fans end Elvis Presley fete with concert.
# 393  UK: Volcano buries studio where rock legends r...
# ...

# %%
texts_pd['topic'] = [topics[i].argmax() for i in range(len(texts))]
texts_pd
# Out:
# C:\Users\247\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                                  title  topic
# 0    UK: Prince Charles spearheads British royal re...     18
# 1    GERMANY: Historic Dresden church rising from W...      1
# 2    INDIA: Mother Teresa's condition said still un...      7
# 3    UK: Palace warns British weekly over Charles p...     11
# 4    INDIA: Mother Teresa, slightly stronger, bless...      1
# ..                                                 ...    ...
# 390  CANADA: FEATURE - French-speaking Quebec celeb...     18
# 391  BULGARIA: FEATURE - Bulgarian opera stars are ...     13
# 392     USA: Fans end Elvis Presley fete with concert.     12
# ...

# %%
for i in range(len(texts)):
    print("{} (topic: {})".format(texts[i], topics[i].argmax()))
# Out:
# UK: Prince Charles spearheads British royal revolution. (topic: 18)
# GERMANY: Historic Dresden church rising from WW2 ashes. (topic: 1)
# INDIA: Mother Teresa's condition said still unstable. (topic: 7)
# UK: Palace warns British weekly over Charles pictures. (topic: 11)
# INDIA: Mother Teresa, slightly stronger, blesses nuns. (topic: 1)
# INDIA: Mother Teresa's condition unchanged, thousands pray. (topic: 7)
# INDIA: Mother Teresa shows signs of strength, blesses nuns. (topic: 1)
# INDIA: Mother Teresa's condition improves, many pray. (topic: 1)
# INDIA: Mother Teresa improves, nuns pray for "miracle". (topic: 1)
# UK: Charles under fire over prospect of Queen Camilla. (topic: 18)
# UK: Britain tells Charles to forget Camilla. (topic: 18)
# COTE D'IVOIRE: FEATURE - Quiet homecoming for reprieved Ivory Coast maid. (topic: 10)
# INDIA: Mother Teresa ("I want to go home") sits and prays. (topic: 1)
# INDIA: Mother Teresa nears end of crisis, nuns rejoice. (topic: 1)
# ...

# %%
import numpy as np
import pyLDAvis
from biterm.btm import oBTM 
from sklearn.feature_extraction.text import CountVectorizer
from biterm.utility import vec_to_biterms, topic_summuary # helper functions

if __name__ == "__main__":

    texts = open('C:/Users/247/Documents/Python Scripts/datasets/reuters.titles').read().splitlines() # path of data file

    # vectorize texts
    vec = CountVectorizer(stop_words='english')
    X = vec.fit_transform(texts).toarray()

    # get vocabulary
    vocab = np.array(vec.get_feature_names())

    # get biterms
    biterms = vec_to_biterms(X)

    # create btm
    btm = oBTM(num_topics=20, V=vocab)

    print("\n\n Train Online BTM ..")
    for i in range(0, len(biterms), 100): # prozess chunk of 200 texts
        biterms_chunk = biterms[i:i + 100]
        btm.fit(biterms_chunk, iterations=50)
    topics = btm.transform(biterms)

    print("\n\n Visualize Topics ..")
    vis = pyLDAvis.prepare(btm.phi_wz.T, topics, np.count_nonzero(X, axis=1), vocab, np.sum(X, axis=0))
    pyLDAvis.save_html(vis, 'C:/Users/247/Documents/Python Scripts/online_btm.html')  # path to output

    print("\n\n Topic coherence ..")
    topic_summuary(btm.phi_wz.T, X, vocab, 10)

    print("\n\n Texts & Topics ..")
    for i in range(len(texts)):
        print("{} (topic: {})".format(texts[i], topics[i].argmax()))
# Out:
# C:\Users\247\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   0%|                                                                                           | 0/50 [00:00<?, ?it/s]
#  Train Online BTM ..
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:11<00:00,  4.45it/s]
#  Visualize Topics ..
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python38\site-packages\pyLDAvis\_display.py in save_html(data, fileobj, **kwargs)
#     349     try:
# --> 350         if isinstance(fileobj, basestring):
# ...
